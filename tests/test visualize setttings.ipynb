# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tabulate import tabulate

plt.style.use("../auri.mplstyle")

pd.options.display.unicode.east_asian_width = True

# %%
# Sample plot to test matplotlib and style
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.figure(figsize=(6, 6))
plt.gca().set_aspect("equal")
plt.plot(x, y, label="sin(x)")
plt.title("Sample Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")


plt.legend()
plt.show()

# %%
# Test DataFrame display with East Asian characters
df = pd.DataFrame(
    {
        "English": ["apple", "banana", "cherry"],
        "Japanese": ["りんご", "バナナ", "さくらんぼ"],
        "Chinese": ["苹果", "香蕉", "樱桃"],
    }
)
print(df)
# Out:
#   English    Japanese Chinese
# 0   apple      りんご    苹果
# 1  banana      バナナ    香蕉
# 2  cherry  さくらんぼ    樱桃
